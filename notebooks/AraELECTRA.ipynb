# %% [markdown]
# <a href="https://colab.research.google.com/github/ARBML/adawat/blob/main/notebooks/AraELECTRA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -q transformers
# Out:
#      |████████████████████████████████| 4.9 MB 16.6 MB/s
#      |████████████████████████████████| 163 kB 44.9 MB/s
#      |████████████████████████████████| 6.6 MB 54.0 MB/s

# %%
from transformers import pipeline

fill_mask = pipeline(
    "fill-mask",
    model="aubmindlab/araelectra-base-generator",
    tokenizer="aubmindlab/araelectra-base-generator"
)

fill_mask(" عاصمة لبنان هي [MASK] .")
# Out:
# Downloading:   0%|          | 0.00/499 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/238M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/393 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/825k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/2.64M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/112 [00:00<?, ?B/s]
# [{'score': 0.35070282220840454,
#   'token': 2079,
#   'token_str': 'بيروت',
#   'sequence': 'عاصمة لبنان هي بيروت.'},
#  {'score': 0.0671466663479805,
#   'token': 911,
#   'token_str': 'لبنان',
#   'sequence': 'عاصمة لبنان هي لبنان.'},
#  {'score': 0.039008475840091705,
#   'token': 3306,
#   'token_str': 'القدس',
#   'sequence': 'عاصمة لبنان هي القدس.'},
#  {'score': 0.028759561479091644,
#   'token': 4861,
#   'token_str': 'طرابلس',
#   'sequence': 'عاصمة لبنان هي طرابلس.'},
#  {'score': 0.023784920573234558,
#   'token': 3743,
#   'token_str': 'باريس',
#   'sequence': 'عاصمة لبنان هي باريس.'}]
