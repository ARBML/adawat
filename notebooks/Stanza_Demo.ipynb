# %% [markdown]
# <a href="https://colab.research.google.com/github/ARBML/adawat/blob/main/notebooks/Stanza_Demo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install stanza
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 691 kB 9.8 MB/s
# ...
#      |████████████████████████████████| 216 kB 51.0 MB/s
# ...
#   Created wheel for emoji: filename=emoji-2.1.0-py3-none-any.whl size=212392 sha256=77ece81465e3f5885b06bf4ca28b54a8041a93a7fab3efee32f285c15c75544e
#   Stored in directory: /root/.cache/pip/wheels/77/75/99/51c2a119f4cfd3af7b49cc57e4f737bed7e40b348a85d82804
# Successfully built emoji
# ...

# %%
import stanza

# %%
stanza.download('ar')       # This downloads the Arabic models for the neural pipeline
nlp = stanza.Pipeline('ar') # This sets up a default neural pipeline in Arabic
# Out:
# ...
# INFO:stanza:Downloading default packages for language: ar (Arabic) ...
# ...
# INFO:stanza:Finished downloading models and saved to /root/stanza_resources.
# INFO:stanza:Checking for updates to resources.json in case models have been updated.  Note: this behavior can be turned off with download_method=None or download_method=DownloadMethod.REUSE_RESOURCES
# ...
# INFO:stanza:Loading these models for language: ar (Arabic):
# ...
# | Processor | Package |
# -----------------------
# | tokenize  | padt    |
# | mwt       | padt    |
# | pos       | padt    |
# | lemma     | padt    |
# | depparse  | padt    |
# | ner       | aqmar   |
# ...
#
# INFO:stanza:Use device: cpu
# INFO:stanza:Loading: tokenize
# INFO:stanza:Loading: mwt
# INFO:stanza:Loading: pos
# INFO:stanza:Loading: lemma
# INFO:stanza:Loading: depparse
# INFO:stanza:Loading: ner
# INFO:stanza:Done loading processors!

# %%
doc = nlp("قفز الثعلب البني السريع فوق الكلب الكسول.")
print(doc)
# Out:
# [
#   [
#     {
#       "id": 1,
#       "text": "قفز",
#       "lemma": "قَفَز",
#       "upos": "VERB",
#       "xpos": "VP-A-3MS--",
#       "feats": "Aspect=Perf|Gender=Masc|Number=Sing|Person=3|Voice=Act",
#       "head": 0,
#       "deprel": "root",
#       "start_char": 0,
#       "end_char": 3,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 2,
#       "text": "الثعلب",
#       "lemma": "ثُعلِب",
#       "upos": "NOUN",
#       "xpos": "N------S1D",
#       "feats": "Case=Nom|Definite=Def|Number=Sing",
#       "head": 1,
#       "deprel": "nsubj",
#       "start_char": 4,
#       "end_char": 10,
#       "ner": "O",
#       "multi_ner": [
#         "O"
#       ]
#     },
#     {
#       "id": 3,
#       "text": "البني",
#       "lemma": "البني",
#       "upos": "X",
#       "xpos": "U---------",
#       "head": 2,
#       "deprel": "nmod",
#       "start_char": 11,
#       "end_char": 16,
#       "ner": "O",
# ...

# %%
doc.sentences[0].print_dependencies()
# Out:
# ('قفز', 0, 'root')
# ('الثعلب', 1, 'nsubj')
# ('البني', 2, 'nmod')
# ('السريع', 2, 'amod')
# ('فوق', 6, 'case')
# ('الكلب', 1, 'obl')
# ('الكسول', 6, 'amod')
# ('.', 1, 'punct')

# %%
for i, sent in enumerate(doc.sentences):
    print("[الجملذ {}]".format(i+1))
    for word in sent.words:
        print("{:12s}\t{:12s}\t{:6s}\t{:d}\t{:12s}".format(\
              word.text, word.lemma, word.pos, word.head, word.deprel))
    print("")
# Out:
# [الجملذ 1]
# قفز         	قَفَز       	VERB  	0	root
# الثعلب      	ثُعلِب      	NOUN  	1	nsubj
# البني       	البني       	X     	2	nmod
# السريع      	سَرِيع      	ADJ   	2	amod
# فوق         	فَوقَ       	ADP   	6	case
# الكلب       	كُلب        	NOUN  	1	obl
# الكسول      	كَسُول      	ADJ   	6	amod
# .           	.           	PUNCT 	1	punct
