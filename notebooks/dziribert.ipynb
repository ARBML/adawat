# %% [markdown]
# <a href="https://colab.research.google.com/github/ARBML/adawat/blob/main/notebooks/dziribert.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -q transformers
# Out:
#      |████████████████████████████████| 5.3 MB 5.3 MB/s
#      |████████████████████████████████| 163 kB 55.2 MB/s
#      |████████████████████████████████| 7.6 MB 43.9 MB/s

# %% [markdown]
# We load the model and tokenizer

# %%
from transformers import BertTokenizer, BertForMaskedLM

tokenizer = BertTokenizer.from_pretrained("alger-ia/dziribert")
model = BertForMaskedLM.from_pretrained("alger-ia/dziribert")
# Out:
# Downloading:   0%|          | 0.00/446k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/176 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/620 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/498M [00:00<?, ?B/s]

# %% [markdown]
# We use the model for predicting masked tokens

# %%
from transformers import pipeline

pipe = pipeline('fill-mask', model=model, tokenizer=tokenizer)

pipe("rouhi ya dzayer [MASK]")
# Out:
# [{'score': 0.6138303875923157,
#   'token': 20894,
#   'token_str': 'r o u h i',
#   'sequence': 'rouhi ya dzayer rouhi'},
#  {'score': 0.09452679753303528,
#   'token': 3308,
#   'token_str': 'ر و ح ي',
#   'sequence': 'rouhi ya dzayer روحي'},
#  {'score': 0.02861395850777626,
#   'token': 20,
#   'token_str': '.',
#   'sequence': 'rouhi ya dzayer.'},
#  {'score': 0.014298412948846817,
#   'token': 7,
#   'token_str': '!',
#   'sequence': 'rouhi ya dzayer!'},
#  {'score': 0.010290710255503654,
#   'token': 41177,
#   'token_str': 'ب س ل ا م ة',
#   'sequence': 'rouhi ya dzayer بسلامة'}]
